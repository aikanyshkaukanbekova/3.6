# %% [markdown]
# # Индивидуальное задание

# %%
# Создаем кубик рубик
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np


# Создаем ось
axes = [5, 5, 5]

# Создаем данные
data = np.ones(axes, dtype=bool)

# Прозрачность
alpha = 0.9

# Цвета
colors = np.empty(axes + [4], dtype=np.float32)

colors[0] = [1, 0, 0, alpha] # red
colors[1] = [0, 1, 0, alpha] # green
colors[2] = [0, 0, 1, alpha] # blue
colors[3] = [1, 1, 0, alpha] # yellow
colors[4] = [1, 1, 1, alpha] # grey

# графический рисунок
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# размеры, расположение цветов
ax.voxels(data, facecolors=colors, edgecolors='grey')
# Out:
# {(0, 0, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d2a280>,
#  (0, 0, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d41370>,
#  (0, 1, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d41670>,
#  (0, 1, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d41970>,
#  (0, 2, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d41c70>,
#  (0, 2, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d41fa0>,
#  (0, 3, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d502e0>,
#  (0, 3, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d505e0>,
#  (0, 4, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d508e0>,
#  (0, 4, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d50be0>,
#  (1, 0, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d50ee0>,
#  (1, 0, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d5f220>,
#  (1, 1, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d5f520>,
#  (1, 1, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d5f820>,
#  (1, 2, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d5fb20>,
#  (1, 2, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d5fe20>,
#  (1, 3, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d6e160>,
#  (1, 3, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d6e460>,
#  (1, 4, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d6e760>,
#  (1, 4, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d6ea60>,
#  (2, 0, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d6ed60>,
#  (2, 0, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d6ef70>,
#  (2, 1, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d7b3a0>,
#  (2, 1, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d7b6a0>,
#  (2, 2, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d7b9a0>,
#  (2, 2, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d7bca0>,
#  (2, 3, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d7bfa0>,
#  (2, 3, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d8a2e0>,
#  (2, 4, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d8a5e0>,
#  (2, 4, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d8a8e0>,
#  (3, 0, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d8abe0>,
#  (3, 0, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d8aee0>,
#  (3, 1, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d9c220>,
#  (3, 1, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d9c520>,
#  (3, 2, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d9c820>,
#  (3, 2, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d9cb20>,
#  (3, 3, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56d9ce20>,
#  (3, 3, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56daa160>,
#  (3, 4, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56daa460>,
#  (3, 4, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56daa760>,
#  (4, 0, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56daaa60>,
#  (4, 0, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56daad60>,
#  (4, 1, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56daaf70>,
#  (4, 1, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56db73a0>,
#  (4, 2, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56db76a0>,
#  (4, 2, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56db79a0>,
#  (4, 3, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56db7ca0>,
#  (4, 3, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56db7fa0>,
#  (4, 4, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dc92e0>,
#  (4, 4, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dc95e0>,
#  (0, 0, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dc98e0>,
#  (4, 0, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dc9be0>,
#  (0, 0, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dc9ee0>,
#  (4, 0, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dd8220>,
#  (0, 0, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dd8520>,
#  (4, 0, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dd8820>,
#  (0, 1, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dd8b20>,
#  (4, 1, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56dd8e20>,
#  (0, 1, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56de6160>,
#  (4, 1, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56de6460>,
#  (0, 1, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56de6760>,
#  (4, 1, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56de6a60>,
#  (0, 2, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56de6d60>,
#  (4, 2, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56de6f70>,
#  (0, 2, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56cfcdc0>,
#  (4, 2, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56df82e0>,
#  (0, 2, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56df85e0>,
#  (4, 2, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56df88e0>,
#  (0, 3, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56df8be0>,
#  (4, 3, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56df8ee0>,
#  (0, 3, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e09220>,
#  (4, 3, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e09520>,
#  (0, 3, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b563086d0>,
#  (4, 3, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56c64d60>,
#  (0, 4, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56c5acd0>,
#  (4, 4, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56a93c70>,
#  (0, 4, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e098b0>,
#  (4, 4, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e09bb0>,
#  (0, 4, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e09eb0>,
#  (4, 4, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e201f0>,
#  (1, 0, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e204f0>,
#  (1, 4, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e207f0>,
#  (2, 0, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e20af0>,
#  (2, 4, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e20df0>,
#  (3, 0, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e20fd0>,
#  (3, 4, 1): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e2f430>,
#  (1, 0, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e2f730>,
#  (1, 4, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e2fa30>,
#  (2, 0, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e2fd30>,
#  (2, 4, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e2ff40>,
#  (3, 0, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e3e370>,
#  (3, 4, 2): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e3e670>,
#  (1, 0, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e3e970>,
#  (1, 4, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e3ec70>,
#  (2, 0, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e3ef70>,
#  (2, 4, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e4d2b0>,
#  (3, 0, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e4d5b0>,
#  (3, 4, 3): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x21b56e4d8b0>}
